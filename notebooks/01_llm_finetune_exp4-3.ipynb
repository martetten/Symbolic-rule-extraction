# %%
import sys
sys.path.append("..")
import os
import torch
import json
import yaml
from pathlib import Path
from datasets import DatasetDict, load_from_disk
from peft import LoraConfig, get_peft_model, TaskType, prepare_model_for_kbit_training

from transformers import AutoTokenizer, AutoModelForCausalLM
from src.data import PROJECT_ROOT
from src.dataset_cot import prepare_direct_pythia_dataset, get_cot_prompt_template, evaluate_cot_capability
from src.llm_upgrade import (
    prepare_model_for_finetune,
    train_lora_model,
    save_finetuned_model,
    wrap_for_transformer_lens,
    create_quantization_config
)

# %% [markdown]
# # Параметры (q)LoRA

# %%
EXP_ID = "exp4-3"
MODEL_NAME = "EleutherAI/pythia-1b-deduped"
VARIANT = "depth-1"
USE_SMALL = False

# %%
EPOCHS = 5
BATCH_SIZE = 2
GRADIENT_ACCUMULATION_STEPS = 8
LEARNING_RATE = 1.5e-4
MAX_LENGTH = 512
SAVE_STEPS = 1000
LOGGING_STEPS = 500
EVAL_STEPS = 500

# %%
LORA_R = 32
LORA_ALPHA = 64
LORA_DROPOUT = 0.1

# %%
TARGET_MODULES = ["query_key_value", "dense", "dense_h_to_4h", "dense_4h_to_h"]

# %%
OUTPUT_DIR = str(PROJECT_ROOT / f"results/checkpoints/finetune/{EXP_ID}")
ADAPTER_SAVE_PATH = str(PROJECT_ROOT / f"results/checkpoints/finetune/{EXP_ID}/lora_final")

# %%
cache_path = PROJECT_ROOT / "data" / "processed" / f"ruletaker_{VARIANT}"
raw_dataset = load_from_disk(str(cache_path))

# %%
# TRAIN_SIZE = 10000
# DEV_SIZE = 1000
SEED = 42

# %% [markdown]
# # Подготовка датасета

# %%
train_subset = raw_dataset["train"].shuffle(seed=SEED)
dev_subset = raw_dataset["dev"].shuffle(seed=SEED)

# %%
train_dataset = prepare_direct_pythia_dataset(train_subset)
dev_dataset   = prepare_direct_pythia_dataset(dev_subset)

# %%
len(train_dataset)
# Out:
# 61699

# %%
len(dev_subset)
# Out:
# 8870

# %%
direct_dir = PROJECT_ROOT / "data" / "processed" / f"ruletaker_{VARIANT}_direct_pythia"
if dev_dataset:
    DatasetDict({"train": train_dataset, "dev": dev_dataset, "test": raw_dataset["test"]}).save_to_disk(str(direct_dir))
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/61699 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/8870 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/17788 [00:00<?, ? examples/s]

# %% [markdown]
# # Обучение

# %%
# qlora
quantization_config = create_quantization_config(use_4bit=True)

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# %%
base_model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=quantization_config,
    device_map="auto",
    torch_dtype=torch.bfloat16,
    attn_implementation="eager"  # Flash Attention часто нестабилен с LoRA на Windows
)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!

# %%
base_model = prepare_model_for_kbit_training(base_model)

# %%
lora_cfg = LoraConfig(
    r=LORA_R,
    lora_alpha=LORA_ALPHA,
    lora_dropout=LORA_DROPOUT,
    target_modules=TARGET_MODULES,
    task_type=TaskType.CAUSAL_LM,
    inference_mode=False
)

# %%
model = get_peft_model(base_model, lora_cfg)
model.print_trainable_parameters()
# Out:
# trainable params: 16,777,216 || all params: 1,028,558,848 || trainable%: 1.6311

# %%
train_config = {
    "output_dir": OUTPUT_DIR,
    "epochs": EPOCHS,
    "batch_size": BATCH_SIZE,
    "gradient_accumulation_steps": GRADIENT_ACCUMULATION_STEPS,
    "learning_rate": LEARNING_RATE,
    "max_length": MAX_LENGTH,
    "logging_steps": LOGGING_STEPS,
    "save_steps": SAVE_STEPS,
    "eval_steps": EVAL_STEPS,
    "use_wandb": False
}

# %%
trained_model, metrics = train_lora_model(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_dataset,
    eval_dataset=dev_dataset,
    config=train_config,
    max_length=MAX_LENGTH
)
# Out:
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='6516' max='19285' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 6516/19285 4:45:19 < 9:19:18, 0.38 it/s, Epoch 1.69/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.948300</td>
#       <td>0.753627</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.708000</td>
#       <td>0.725478</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.681500</td>
#       <td>0.721385</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.673700</td>
#       <td>0.716403</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.662100</td>
#       <td>0.719898</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.650100</td>
#       <td>0.720255</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.632100</td>
#       <td>0.728845</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.604100</td>
#       <td>0.757163</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.564400</td>
#       <td>0.778806</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.522600</td>
#       <td>0.823452</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.475500</td>
#       <td>0.865934</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.430000</td>
#       <td>0.944700</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.382500</td>
#       <td>0.995550</td>
#     </tr>
#   </tbody>
# </table><p>
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 trained_model, metrics = train_lora_model(
#       2     model=model,
#       3     tokenizer=tokenizer,
#       4     train_dataset=train_dataset,
#       5     eval_dataset=dev_dataset,
#       6     config=train_config,
#       7     max_length=MAX_LENGTH
#       8 )
#
# File c:\MyPythonProjects\mephi_diss\notebooks\..\src\llm_upgrade.py:211, in train_lora_model(model, tokenizer, train_dataset, config, eval_dataset, max_length)
#     190 training_args = create_training_args(
#     191     output_dir=config.get("output_dir", str(PROJECT_ROOT / "results/checkpoints/finetune")),
#     192     epochs=config.get("epochs", 3),
#    (...)    200     eval_dataset_provided=(eval_dataset is not None)
#     201 )
#     203 trainer = Trainer(
#     204     model=model,
#     205     args=training_args,
#    (...)    208     data_collator=data_collator
#     209 )
# --> 211 train_result = trainer.train()
#     213 return trainer.model, train_result.metrics
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\transformers\trainer.py:2325, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2323         hf_hub_utils.enable_progress_bars()
#    2324 else:
# -> 2325     return inner_training_loop(
#    2326         args=args,
#    2327         resume_from_checkpoint=resume_from_checkpoint,
#    2328         trial=trial,
#    2329         ignore_keys_for_eval=ignore_keys_for_eval,
#    2330     )
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\transformers\trainer.py:2674, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2667 context = (
#    2668     functools.partial(self.accelerator.no_sync, model=model)
#    2669     if i != len(batch_samples) - 1
#    2670     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2671     else contextlib.nullcontext
#    2672 )
#    2673 with context():
# -> 2674     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2676 if (
#    2677     args.logging_nan_inf_filter
#    2678     and not is_torch_xla_available()
#    2679     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2680 ):
#    2681     # if loss is nan or inf simply add the average of previous logged losses
#    2682     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\transformers\trainer.py:4020, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    4017     return loss_mb.reduce_mean().detach().to(self.args.device)
#    4019 with self.compute_loss_context_manager():
# -> 4020     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    4022 del inputs
#    4023 if (
#    4024     self.args.torch_empty_cache_steps is not None
#    4025     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    4026 ):
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\transformers\trainer.py:4110, in Trainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    4108         kwargs["num_items_in_batch"] = num_items_in_batch
#    4109     inputs = {**inputs, **kwargs}
# -> 4110 outputs = model(**inputs)
#    4111 # Save past state if it exists
#    4112 # TODO: this needs to be fixed and made cleaner later.
#    4113 if self.args.past_index >= 0:
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\accelerate\utils\operations.py:823, in convert_outputs_to_fp32.<locals>.forward(*args, **kwargs)
#     822 def forward(*args, **kwargs):
# --> 823     return model_forward(*args, **kwargs)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\accelerate\utils\operations.py:811, in ConvertOutputsToFp32.__call__(self, *args, **kwargs)
#     810 def __call__(self, *args, **kwargs):
# --> 811     return convert_to_fp32(self.model_forward(*args, **kwargs))
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\amp\autocast_mode.py:44, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      41 @functools.wraps(func)
#      42 def decorate_autocast(*args, **kwargs):
#      43     with autocast_instance:
# ---> 44         return func(*args, **kwargs)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\peft\peft_model.py:1923, in PeftModelForCausalLM.forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, task_ids, **kwargs)
#    1921     with self._enable_peft_forward_hooks(**kwargs):
#    1922         kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1923         return self.base_model(
#    1924             input_ids=input_ids,
#    1925             attention_mask=attention_mask,
#    1926             inputs_embeds=inputs_embeds,
#    1927             labels=labels,
#    1928             output_attentions=output_attentions,
#    1929             output_hidden_states=output_hidden_states,
#    1930             return_dict=return_dict,
#    1931             **kwargs,
#    1932         )
#    1934 batch_size = _get_batch_size(input_ids, inputs_embeds)
#    1935 if attention_mask is not None:
#    1936     # concat prompt attention mask
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\peft\tuners\tuners_utils.py:311, in BaseTuner.forward(self, *args, **kwargs)
#     310 def forward(self, *args: Any, **kwargs: Any):
# --> 311     return self.model.forward(*args, **kwargs)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\transformers\utils\generic.py:918, in can_return_tuple.<locals>.wrapper(self, *args, **kwargs)
#     916 if return_dict_passed is not None:
#     917     return_dict = return_dict_passed
# --> 918 output = func(self, *args, **kwargs)
#     919 if not return_dict and not isinstance(output, tuple):
#     920     output = output.to_tuple()
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\transformers\models\gpt_neox\modeling_gpt_neox.py:577, in GPTNeoXForCausalLM.forward(self, input_ids, attention_mask, position_ids, inputs_embeds, head_mask, past_key_values, labels, use_cache, output_attentions, output_hidden_states, cache_position, logits_to_keep, **kwargs)
#     536 @can_return_tuple
#     537 @auto_docstring
#     538 def forward(
#    (...)    552     **kwargs: Unpack[TransformersKwargs],
#     553 ) -> Union[tuple, CausalLMOutputWithPast]:
#     554     r"""
#     555     labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#     556         Labels for computing the left-to-right language modeling loss (next word prediction). Indices should be in
#    (...)    574     >>> prediction_logits = outputs.logits
#     575     ```"""
# --> 577     outputs: BaseModelOutputWithPast = self.gpt_neox(
#     578         input_ids,
#     579         attention_mask=attention_mask,
#     580         position_ids=position_ids,
#     581         head_mask=head_mask,
#     582         inputs_embeds=inputs_embeds,
#     583         past_key_values=past_key_values,
#     584         use_cache=use_cache,
#     585         output_attentions=output_attentions,
#     586         output_hidden_states=output_hidden_states,
#     587         cache_position=cache_position,
#     588         **kwargs,
#     589     )
#     591     hidden_states = outputs.last_hidden_state
#     592     # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\transformers\utils\generic.py:1072, in check_model_inputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#    1069                 monkey_patched_layers.append((module, original_forward))
#    1071 try:
# -> 1072     outputs = func(self, *args, **kwargs)
#    1073 except TypeError as original_exception:
#    1074     # If we get a TypeError, it's possible that the model is not receiving the recordable kwargs correctly.
#    1075     # Get a TypeError even after removing the recordable kwargs -> re-raise the original exception
#    1076     # Otherwise -> we're probably missing `**kwargs` in the decorated function
#    1077     kwargs_without_recordable = {k: v for k, v in kwargs.items() if k not in recordable_keys}
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\transformers\models\gpt_neox\modeling_gpt_neox.py:475, in GPTNeoXModel.forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, past_key_values, use_cache, output_attentions, output_hidden_states, cache_position, **kwargs)
#     472 if output_hidden_states:
#     473     all_hidden_states = all_hidden_states + (hidden_states,)
# --> 475 outputs = layer(
#     476     hidden_states,
#     477     attention_mask=causal_mask,
#     478     position_ids=position_ids,
#     479     head_mask=head_mask[i],
#     480     layer_past=past_key_values,
#     481     use_cache=use_cache,
#     482     output_attentions=output_attentions,
#     483     cache_position=cache_position,
#     484     position_embeddings=position_embeddings,
#     485     **kwargs,
#     486 )
#     487 hidden_states = outputs[0]
#     489 if output_attentions:
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\transformers\modeling_layers.py:93, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      90         message = message.rstrip(",") + "."
#      91         logger.warning_once(message)
# ---> 93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
#      94 return super().__call__(*args, **kwargs)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_compile.py:51, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      48     disable_fn = torch._dynamo.disable(fn, recursive)
#      49     fn.__dynamo_disable = disable_fn  # type: ignore[attr-defined]
# ---> 51 return disable_fn(*args, **kwargs)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#     836 _maybe_set_eval_frame(_callback_from_stance(self.callback))
#     837 try:
# --> 838     return fn(*args, **kwargs)
#     839 finally:
#     840     set_eval_frame(None)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\utils\checkpoint.py:488, in checkpoint(function, use_reentrant, context_fn, determinism_check, debug, *args, **kwargs)
#     483     if context_fn is not noop_context_fn or debug is not False:
#     484         raise ValueError(
#     485             "Passing `context_fn` or `debug` is only supported when "
#     486             "use_reentrant=False."
#     487         )
# --> 488     return CheckpointFunction.apply(function, preserve, *args)
#     489 else:
#     490     gen = _checkpoint_without_reentrant_generator(
#     491         function, preserve, context_fn, determinism_check, debug, *args, **kwargs
#     492     )
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\autograd\function.py:575, in Function.apply(cls, *args, **kwargs)
#     572 if not torch._C._are_functorch_transforms_active():
#     573     # See NOTE: [functorch vjp and autograd interaction]
#     574     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 575     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577 if not is_setup_ctx_defined:
#     578     raise RuntimeError(
#     579         "In order to use an autograd.Function with functorch transforms "
#     580         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     581         "staticmethod. For more details, please see "
#     582         "https://pytorch.org/docs/main/notes/extending.func.html"
#     583     )
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\utils\checkpoint.py:263, in CheckpointFunction.forward(ctx, run_function, preserve_rng_state, *args)
#     260 ctx.save_for_backward(*tensor_inputs)
#     262 with torch.no_grad():
# --> 263     outputs = run_function(*args)
#     264 return outputs
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\transformers\models\gpt_neox\modeling_gpt_neox.py:221, in GPTNeoXLayer.forward(self, hidden_states, attention_mask, position_ids, head_mask, use_cache, layer_past, output_attentions, cache_position, position_embeddings, **kwargs)
#     208 def forward(
#     209     self,
#     210     hidden_states: Optional[torch.FloatTensor],
#    (...)    219     **kwargs: Unpack[FlashAttentionKwargs],
#     220 ):
# --> 221     attn_output, attn_weights = self.attention(
#     222         self.input_layernorm(hidden_states),
#     223         attention_mask=attention_mask,
#     224         position_ids=position_ids,
#     225         layer_past=layer_past,
#     226         head_mask=head_mask,
#     227         use_cache=use_cache,
#     228         output_attentions=output_attentions,
#     229         cache_position=cache_position,
#     230         position_embeddings=position_embeddings,
#     231         **kwargs,
#     232     )
#     233     attn_output = self.post_attention_dropout(attn_output)
#     235     if self.use_parallel_residual:
#     236         # pseudocode:
#     237         # x = x + attn(ln1(x)) + mlp(ln2(x))
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\transformers\models\gpt_neox\modeling_gpt_neox.py:157, in GPTNeoXAttention.forward(self, hidden_states, attention_mask, head_mask, layer_past, output_attentions, cache_position, position_embeddings, **kwargs)
#     154 input_shape = hidden_states.shape[:-1]
#     155 hidden_shape = (*input_shape, -1, 3 * self.head_size)
# --> 157 qkv = self.query_key_value(hidden_states).view(hidden_shape).transpose(1, 2)
#     158 query_states, key_states, value_states = qkv.chunk(3, dim=-1)
#     160 cos, sin = position_embeddings
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\peft\tuners\lora\bnb.py:547, in Linear4bit.forward(self, x, *args, **kwargs)
#     545     result = self.base_layer(x, *args, **kwargs)
#     546 else:
# --> 547     result = self.base_layer(x, *args, **kwargs)
#     548     # As per Tim Dettmers, for 4bit, we need to defensively clone here.
#     549     # The reason is that in some cases, an error can occur that backprop
#     550     # does not work on a manipulated view. This issue may be solved with
#     551     # newer PyTorch versions but this would need extensive testing to be
#     552     # sure.
#     553     result = result.clone()
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\bitsandbytes\nn\modules.py:556, in Linear4bit.forward(self, x)
#     553 bias = None if self.bias is None else self.bias.to(self.compute_dtype)
#     554 weight = self.weight if getattr(quant_state, "packing_format_for_cpu", False) else self.weight.t()
# --> 556 return bnb.matmul_4bit(x, weight, bias=bias, quant_state=quant_state).to(inp_dtype)
#
# KeyboardInterrupt:

# %%
save_finetuned_model(trained_model, tokenizer, ADAPTER_SAVE_PATH)
# Out:
# Адаптер сохранён в C:\MyPythonProjects\mephi_diss\results\checkpoints\finetune\exp3\lora_final

# %% [markdown]
# # Тест дообученной модели

# %%
BEST_CHECKPOINT = 2200
adapter_path = PROJECT_ROOT / f"results/checkpoints/finetune/{EXP_ID}/checkpoint-{BEST_CHECKPOINT}"

# %%
hooked_model, _ = wrap_for_transformer_lens(
    MODEL_NAME,
    str(adapter_path),
    device="cuda"
)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loaded pretrained model EleutherAI/pythia-1b-deduped into HookedTransformer

# %%
eval_prefix = "{theory} {assertion} The assertion is"

# %%
full_test = load_from_disk(str(cache_path))["test"]

# %%
test_acc = evaluate_cot_capability(
    model=hooked_model,
    dataset=full_test,
    prompt_template=eval_prefix,
    batch_size=32,
    device="cuda"
)
# Out:
# Evaluating CoT capability:   0%|          | 0/543 [00:00<?, ?it/s]
# Evaluating CoT capability: 100%|██████████| 543/543 [11:34<00:00,  1.28s/it]

# %%
results = {
    "experiment_id": EXP_ID,
    "model": MODEL_NAME,
    "variant": VARIANT,
    "best_checkpoint": adapter_path.name,
    "val_loss_at_checkpoint": 0.673169,
    "test_accuracy": test_acc,
    "config": {
        "epochs": EPOCHS, "batch_size": BATCH_SIZE, "lora_r": LORA_R, "train_size": TRAIN_SIZE
    }
}

# %%
results_path = Path(OUTPUT_DIR) / "results.json"
with open(results_path, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

# %%
print(f"Experiment: {EXP_ID}")
print(f"Checkpoint: {adapter_path.name}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Results saved: {results_path}")
# Out:
# Experiment: exp3
# Checkpoint: checkpoint-2200
# Test Accuracy: 0.9798
# Results saved: C:\MyPythonProjects\mephi_diss\results\checkpoints\finetune\exp3\results.json

# %% [markdown]
# # Диагностика предсказаний

# %%
test_examples = raw_dataset["test"].select(range(5))
eval_prefix = "{theory} {assertion} The assertion is"

# %%
with torch.no_grad():
    for i, ex in enumerate(test_examples):
        prompt = eval_prefix.format(theory=ex["theory"], assertion=ex["assertion"])
        tokens = hooked_model.to_tokens([prompt], prepend_bos=True).to("cuda")
        logits = hooked_model(tokens)

        # Индексы целевых токенов
        true_id = hooked_model.tokenizer.encode("True", add_special_tokens=False)[-1]
        false_id = hooked_model.tokenizer.encode("False", add_special_tokens=False)[-1]

        # Длина промпта (последний токен находится по этому индексу после добавления BOS)
        prompt_len = len(hooked_model.tokenizer.encode(prompt, add_special_tokens=False))

        logit_t = logits[0, prompt_len, true_id].item()
        logit_f = logits[0, prompt_len, false_id].item()
        pred = "True" if logit_t > logit_f else "False"
        true_label = "True" if ex["label"] else "False"

        print(f"[{i+1}] Предсказание: {pred:5s} | Логиты T/F: {logit_t:+.2f} / {logit_f:+.2f} | Истина: {true_label} | Совпало: {pred == true_label}")
# Out:
# [1] Предсказание: True  | Логиты T/F: +19.38 / +15.50 | Истина: True | Совпало: True
# [2] Предсказание: False | Логиты T/F: +16.62 / +19.38 | Истина: False | Совпало: True
# [3] Предсказание: True  | Логиты T/F: +21.12 / +18.25 | Истина: True | Совпало: True
# [4] Предсказание: False | Логиты T/F: +11.50 / +15.94 | Истина: False | Совпало: True
# [5] Предсказание: True  | Логиты T/F: +16.88 / +13.38 | Истина: True | Совпало: True

# %%
del hooked_model
torch.cuda.empty_cache()
