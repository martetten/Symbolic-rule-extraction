# %%
import sys
sys.path.append("..")
import os
import torch
import json
import yaml
from pathlib import Path
from datasets import DatasetDict, load_from_disk
from peft import LoraConfig, get_peft_model, TaskType, prepare_model_for_kbit_training

from transformers import AutoTokenizer, AutoModelForCausalLM
from src.data import PROJECT_ROOT
from src.dataset_cot import prepare_direct_pythia_dataset, get_cot_prompt_template, evaluate_cot_capability
from src.llm_upgrade import (
    prepare_model_for_finetune,
    train_lora_model,
    save_finetuned_model,
    wrap_for_transformer_lens,
    create_quantization_config
)

# %% [markdown]
# # Параметры (q)LoRA

# %%
EXP_ID = "exp6-1"
MODEL_NAME = "gpt2-large"
VARIANT = "depth-0"
USE_SMALL = False

# %%
EPOCHS = 3
BATCH_SIZE = 2
GRADIENT_ACCUMULATION_STEPS = 8
LEARNING_RATE = 1.0e-4
MAX_LENGTH = 512
SAVE_STEPS = 1000
LOGGING_STEPS = 200
EVAL_STEPS = 200

# %%
LORA_R = 16
LORA_ALPHA = 32
LORA_DROPOUT = 0.05

# %%
TARGET_MODULES = ["c_attn", "c_proj", "c_fc"]

# %%
OUTPUT_DIR = str(PROJECT_ROOT / f"results/checkpoints/finetune/{EXP_ID}")
ADAPTER_SAVE_PATH = str(PROJECT_ROOT / f"results/checkpoints/finetune/{EXP_ID}/lora_final")

# %%
cache_path = PROJECT_ROOT / "data" / "processed" / f"ruletaker_{VARIANT}"
raw_dataset = load_from_disk(str(cache_path))

# %%
# TRAIN_SIZE = 10000
# DEV_SIZE = 1000
SEED = 42

# %% [markdown]
# # Подготовка датасета

# %%
train_subset = raw_dataset["train"].shuffle(seed=SEED)
dev_subset = raw_dataset["dev"].shuffle(seed=SEED)

# %%
train_dataset = prepare_direct_pythia_dataset(train_subset)
dev_dataset   = prepare_direct_pythia_dataset(dev_subset)

# %%
len(train_dataset)
# Out:
# 60557

# %%
len(dev_subset)
# Out:
# 8718

# %%
direct_dir = PROJECT_ROOT / "data" / "processed" / f"ruletaker_{VARIANT}_direct_gpt2"
if dev_dataset:
    DatasetDict({"train": train_dataset, "dev": dev_dataset, "test": raw_dataset["test"]}).save_to_disk(str(direct_dir))
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/60557 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/8718 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/17347 [00:00<?, ? examples/s]

# %% [markdown]
# # Обучение

# %%
# qlora
quantization_config = create_quantization_config(use_4bit=True)

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# %%
base_model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=quantization_config,
    device_map="auto",
    torch_dtype=torch.bfloat16,
    attn_implementation="eager"  # Flash Attention часто нестабилен с LoRA на Windows
)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!

# %%
base_model = prepare_model_for_kbit_training(base_model)

# %%
lora_cfg = LoraConfig(
    r=LORA_R,
    lora_alpha=LORA_ALPHA,
    lora_dropout=LORA_DROPOUT,
    target_modules=TARGET_MODULES,
    task_type=TaskType.CAUSAL_LM,
    inference_mode=False
)

# %%
model = get_peft_model(base_model, lora_cfg)
model.print_trainable_parameters()
# Out:
# trainable params: 11,796,480 || all params: 785,826,560 || trainable%: 1.5012

# %%
train_config = {
    "output_dir": OUTPUT_DIR,
    "epochs": EPOCHS,
    "batch_size": BATCH_SIZE,
    "gradient_accumulation_steps": GRADIENT_ACCUMULATION_STEPS,
    "learning_rate": LEARNING_RATE,
    "max_length": MAX_LENGTH,
    "logging_steps": LOGGING_STEPS,
    "save_steps": SAVE_STEPS,
    "eval_steps": EVAL_STEPS,
    "use_wandb": False
}

# %%
trained_model, metrics = train_lora_model(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_dataset,
    eval_dataset=dev_dataset,
    config=train_config,
    max_length=MAX_LENGTH
)
# Out:
# Map:   0%|          | 0/60557 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8718 [00:00<?, ? examples/s]
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='11355' max='11355' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11355/11355 21:14:08, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>200</td>
#       <td>1.572200</td>
#       <td>0.874042</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.828100</td>
#       <td>0.775270</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.771000</td>
#       <td>0.748984</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.753500</td>
#       <td>0.743898</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.738500</td>
#       <td>0.740336</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.737200</td>
#       <td>0.726495</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.733500</td>
#       <td>0.723281</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.731800</td>
#       <td>0.722015</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.723200</td>
#       <td>0.721921</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.722800</td>
#       <td>0.717710</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.717500</td>
#       <td>0.717139</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.712600</td>
#       <td>0.713346</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.711300</td>
#       <td>0.712611</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.706000</td>
#       <td>0.710606</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.706000</td>
#       <td>0.712569</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.706200</td>
#       <td>0.709940</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.701500</td>
#       <td>0.706426</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.700600</td>
#       <td>0.704234</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.701600</td>
#       <td>0.702157</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.694900</td>
#       <td>0.698135</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.694500</td>
#       <td>0.697940</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.691200</td>
#       <td>0.700215</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.688000</td>
#       <td>0.694509</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.687400</td>
#       <td>0.694032</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.686800</td>
#       <td>0.693697</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.688600</td>
#       <td>0.692921</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.685800</td>
#       <td>0.692467</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.682200</td>
#       <td>0.690057</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.685800</td>
#       <td>0.689431</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.676800</td>
#       <td>0.689067</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>0.676400</td>
#       <td>0.689845</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.682400</td>
#       <td>0.688154</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.678200</td>
#       <td>0.687177</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.678900</td>
#       <td>0.686733</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.676700</td>
#       <td>0.685755</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.678000</td>
#       <td>0.684252</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>0.675200</td>
#       <td>0.683386</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>0.673500</td>
#       <td>0.682826</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>0.674300</td>
#       <td>0.682280</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.672400</td>
#       <td>0.681800</td>
#     </tr>
#     <tr>
#       <td>8200</td>
#       <td>0.671000</td>
#       <td>0.680563</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.668900</td>
#       <td>0.681300</td>
#     </tr>
#     <tr>
#       <td>8600</td>
#       <td>0.669900</td>
#       <td>0.680154</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.665700</td>
#       <td>0.679724</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.670000</td>
#       <td>0.679510</td>
#     </tr>
#     <tr>
#       <td>9200</td>
#       <td>0.668000</td>
#       <td>0.679334</td>
#     </tr>
#     <tr>
#       <td>9400</td>
#       <td>0.668600</td>
#       <td>0.679087</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>0.665800</td>
#       <td>0.679058</td>
#     </tr>
#     <tr>
#       <td>9800</td>
#       <td>0.666700</td>
#       <td>0.678711</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.664600</td>
#       <td>0.678578</td>
#     </tr>
#     <tr>
#       <td>10200</td>
#       <td>0.664500</td>
#       <td>0.678591</td>
#     </tr>
#     <tr>
#       <td>10400</td>
#       <td>0.667500</td>
#       <td>0.678370</td>
#     </tr>
#     <tr>
#       <td>10600</td>
#       <td>0.665800</td>
#       <td>0.678037</td>
#     </tr>
#     <tr>
#       <td>10800</td>
#       <td>0.664500</td>
#       <td>0.678152</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.669900</td>
#       <td>0.678050</td>
#     </tr>
#     <tr>
#       <td>11200</td>
#       <td>0.666100</td>
#       <td>0.678136</td>
#     </tr>
#   </tbody>
# </table><p>
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 2c8f94ab-a24f-482c-83cb-cdee29982018)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: f5493b62-b451-490e-9ea3-6965dcae8de4)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 2s [Retry 2/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: ddf27e24-259f-4af0-ac4f-4ed49b6d9b89)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 4s [Retry 3/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 2b92a2d0-da91-4812-b4d6-5b2a9a0534da)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 8s [Retry 4/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: a04e1a40-9e0c-440b-b896-d549760e19c6)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 8s [Retry 5/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: f69c5ea9-44fa-46a7-9215-3820b5e59212)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\peft\utils\other.py:1394: UserWarning: Unable to fetch remote file due to the following error (MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: f69c5ea9-44fa-46a7-9215-3820b5e59212)') - silently ignoring the lookup for the file config.json in gpt2-large.
#   warnings.warn(
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\peft\utils\save_and_load.py:295: UserWarning: Could not find a config file in gpt2-large - will assume that the vocabulary was not modified.
#   warnings.warn(
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 387e1aa1-a408-4514-8f48-22ad4b8f5fea)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: d533d117-4c0b-4676-8c5d-cec2d3f66f8b)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 2s [Retry 2/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 2af3e5d2-2b08-4ad0-8d1c-1a434a069c79)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 4s [Retry 3/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 212c3435-1432-49db-ab42-38049956825e)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 8s [Retry 4/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: f654afcf-1f24-4cb9-9e9a-71e6ae61496d)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 8s [Retry 5/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 88dcceab-4eaa-48cc-b5d8-fc70a8bd09a5)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\peft\utils\other.py:1394: UserWarning: Unable to fetch remote file due to the following error (MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 88dcceab-4eaa-48cc-b5d8-fc70a8bd09a5)') - silently ignoring the lookup for the file config.json in gpt2-large.
#   warnings.warn(
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\peft\utils\save_and_load.py:295: UserWarning: Could not find a config file in gpt2-large - will assume that the vocabulary was not modified.
#   warnings.warn(
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: c4617e17-6cb8-4843-9ca3-e8416f0cd060)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 2d27fa99-f579-42f1-95dc-1ba77d6ecdb8)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 2s [Retry 2/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 088725a7-e1a7-4dc8-b38b-689dc7650c18)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 4s [Retry 3/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 1678883d-7c69-413c-81b5-13158d794a66)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 8s [Retry 4/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 619f9c91-0b4b-407a-8bcb-ff45b7cc8639)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# Retrying in 8s [Retry 5/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 3c43467e-fa49-4c52-8a8c-ce2c7a12e4aa)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/config.json
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\peft\utils\other.py:1394: UserWarning: Unable to fetch remote file due to the following error (MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 3c43467e-fa49-4c52-8a8c-ce2c7a12e4aa)') - silently ignoring the lookup for the file config.json in gpt2-large.
#   warnings.warn(
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\peft\utils\save_and_load.py:295: UserWarning: Could not find a config file in gpt2-large - will assume that the vocabulary was not modified.
#   warnings.warn(
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\torch\_dynamo\eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)

# %%
save_finetuned_model(trained_model, tokenizer, ADAPTER_SAVE_PATH)
# Out:
# Адаптер сохранён в C:\MyPythonProjects\mephi_diss\results\checkpoints\finetune\exp6-1\lora_final

# %% [markdown]
# # Тест дообученной модели

# %%
BEST_CHECKPOINT = 11000
adapter_path = PROJECT_ROOT / f"results/checkpoints/finetune/{EXP_ID}/checkpoint-{BEST_CHECKPOINT}"

# %%
hooked_model, _ = wrap_for_transformer_lens(
    MODEL_NAME,
    str(adapter_path),
    device="cuda"
)
# Out:
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\peft\tuners\lora\layer.py:2285: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
# Loaded pretrained model gpt2-large into HookedTransformer

# %%
eval_prefix = "{theory} {assertion} The assertion is"

# %%
full_test = load_from_disk(str(cache_path))["test"]

# %%
test_acc = evaluate_cot_capability(
    model=hooked_model,
    dataset=full_test,
    prompt_template=eval_prefix,
    batch_size=32,
    device="cuda"
)
# Out:
# Evaluating CoT capability: 100%|██████████| 543/543 [1:39:58<00:00, 11.05s/it]

# %%
results = {
    "experiment_id": EXP_ID,
    "model": MODEL_NAME,
    "variant": VARIANT,
    "best_checkpoint": f"checkpoint-{BEST_CHECKPOINT}",
    "val_loss_at_checkpoint": 0.678050,
    "test_accuracy": float(test_acc),
    "config": {
        "epochs": EPOCHS, "batch_size": BATCH_SIZE, "lora_r": LORA_R, "train_size": "full"
    }
}

# %%
results_path = Path(OUTPUT_DIR) / "results.json"
with open(results_path, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

# %%
print(f"Experiment: {EXP_ID}")
print(f"Checkpoint: {adapter_path.name}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Results saved: {results_path}")
# Out:
# Experiment: exp6-1
# Checkpoint: checkpoint-11000
# Test Accuracy: 0.9983
# Results saved: C:\MyPythonProjects\mephi_diss\results\checkpoints\finetune\exp6-1\results.json

# %% [markdown]
# # Диагностика предсказаний

# %%
test_examples = raw_dataset["test"].select(range(5))
eval_prefix = "{theory} {assertion} The assertion is"

# %%
with torch.no_grad():
    for i, ex in enumerate(test_examples):
        prompt = eval_prefix.format(theory=ex["theory"], assertion=ex["assertion"])
        tokens = hooked_model.to_tokens([prompt], prepend_bos=True).to("cuda")
        logits = hooked_model(tokens)

        # Индексы целевых токенов
        true_id = hooked_model.tokenizer.encode("True", add_special_tokens=False)[-1]
        false_id = hooked_model.tokenizer.encode("False", add_special_tokens=False)[-1]

        # Длина промпта (последний токен находится по этому индексу после добавления BOS)
        prompt_len = len(hooked_model.tokenizer.encode(prompt, add_special_tokens=False))

        logit_t = logits[0, prompt_len, true_id].item()
        logit_f = logits[0, prompt_len, false_id].item()
        pred = "True" if logit_t > logit_f else "False"
        true_label = "True" if ex["label"] else "False"

        print(f"[{i+1}] Предсказание: {pred:5s} | Логиты T/F: {logit_t:+.2f} / {logit_f:+.2f} | Истина: {true_label} | Совпало: {pred == true_label}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       2 for i, ex in enumerate(test_examples):
#       3     prompt = eval_prefix.format(theory=ex["theory"], assertion=ex["assertion"])
# ----> 4     tokens = hooked_model.to_tokens([prompt], prepend_bos=True).to("cuda")
#       5     logits = hooked_model(tokens)
#       7     # Индексы целевых токенов
#
# NameError: name 'hooked_model' is not defined

# %%
del hooked_model
torch.cuda.empty_cache()
