# %%
import sys
sys.path.append("..")
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from IPython.display import HTML, display
from pathlib import Path
from datasets import load_from_disk
from tqdm import tqdm
from sklearn.tree import plot_tree
import json
from rulefit import RuleFit
import gc

from src.data import PROJECT_ROOT
from src.llm_upgrade import wrap_for_transformer_lens
from src.sae_test import TopKSAE
from src.rule_extraction import (
    compute_sae_activations_batched,
    compute_dt_fidelity,
    compute_best_single_rule,
    compute_union_coverage,
    rank_features_by_logic,
    generate_threshold_rules,
    extract_semantic_annotations,
    visualize_token_attributions,
    integrated_gradients_latent
)

# %%
EXP_ID = "exp6-1"
MODEL_NAME = "gpt2-large"
VARIANT = "depth-0"
ADAPTER_PATH = str(PROJECT_ROOT / f"results/checkpoints/finetune/{EXP_ID}/checkpoint-11000")
PROBING_JSON = PROJECT_ROOT / "results/probing/probe_gpt2-large(qLoRA)_depth-0_resid_post_last.json"
with open(PROBING_JSON, "r", encoding="utf-8") as f:
    probing_data = json.load(f)
BEST_LAYER = probing_data["summary"]["best_layer"]
SAE_DIR = PROJECT_ROOT / f"results/sae/{EXP_ID}_centered/layer_{BEST_LAYER}"
SAE_PATH = str(SAE_DIR / "sae_final.pt")

# %%
BASELINE_DIR = PROJECT_ROOT / "results/baselines" / EXP_ID
BASELINE_CACHE_DIR = BASELINE_DIR / "cache"

K_CANDIDATES = [50, 100, 200, 500]
CANDIDATE_POOL_K = 50
MAX_DEPTH = 3

# %%
torch.cuda.empty_cache()
gc.collect()
# Out:
# 8138

# %% [markdown]
# # Загрузка модели, датасета и SAE

# %%
hooked_model, tokenizer = wrap_for_transformer_lens(MODEL_NAME, ADAPTER_PATH, device="cuda")
hooked_model.eval()
# Out:
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/tokenizer_config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 9104ae94-30b0-4def-b240-08da55f370a3)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/tokenizer_config.json
# Retrying in 1s [Retry 1/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/tokenizer_config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: eeea8054-0339-4362-bb89-a4ee28f09a5d)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/tokenizer_config.json
# Retrying in 2s [Retry 2/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/tokenizer_config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 8b986941-07f7-466f-9149-7ed8b6b7494f)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/tokenizer_config.json
# Retrying in 4s [Retry 3/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/tokenizer_config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: b2c76f9e-b8cc-42d4-bd0d-f0aa7a107a4d)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/tokenizer_config.json
# Retrying in 8s [Retry 4/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/tokenizer_config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 7be9e468-6bd6-42dd-83bc-98e2461212aa)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/tokenizer_config.json
# Retrying in 8s [Retry 5/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /gpt2-large/resolve/main/tokenizer_config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 5d51994e-90a2-4d60-bd71-7470de6e8707)')' thrown while requesting HEAD https://huggingface.co/gpt2-large/resolve/main/tokenizer_config.json
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\peft\tuners\lora\layer.py:2285: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
# Loaded pretrained model gpt2-large into HookedTransformer
# HookedTransformer(
#   (embed): Embed()
#   (hook_embed): HookPoint()
#   (pos_embed): PosEmbed()
#   (hook_pos_embed): HookPoint()
#   (blocks): ModuleList(
#     (0-35): 36 x TransformerBlock(
#       (ln1): LayerNorm(
#         (hook_scale): HookPoint()
#         (hook_normalized): HookPoint()
#       )
#       (ln2): LayerNorm(
#         (hook_scale): HookPoint()
#         (hook_normalized): HookPoint()
#       )
#       (attn): Attention(
#         (hook_k): HookPoint()
#         (hook_q): HookPoint()
#         (hook_v): HookPoint()
#         (hook_z): HookPoint()
#         (hook_attn_scores): HookPoint()
#         (hook_pattern): HookPoint()
#         (hook_result): HookPoint()
#       )
#       (mlp): MLP(
#         (hook_pre): HookPoint()
#         (hook_post): HookPoint()
#       )
#       (hook_attn_in): HookPoint()
#       (hook_q_input): HookPoint()
#       (hook_k_input): HookPoint()
#       (hook_v_input): HookPoint()
#       (hook_mlp_in): HookPoint()
#       (hook_attn_out): HookPoint()
#       (hook_mlp_out): HookPoint()
#       (hook_resid_pre): HookPoint()
#       (hook_resid_mid): HookPoint()
#       (hook_resid_post): HookPoint()
#     )
#   )
#   (ln_final): LayerNorm(
#     (hook_scale): HookPoint()
#     (hook_normalized): HookPoint()
#   )
#   (unembed): Unembed()
# )

# %%
cache_path = PROJECT_ROOT / "data" / "processed" / f"ruletaker_{VARIANT}"
full_test = load_from_disk(str(cache_path))["test"]

# %%
checkpoint = torch.load(SAE_PATH, map_location="cuda", weights_only=False)
K_SAE_CFG = checkpoint['config']['k']
D_SAE = checkpoint['config']['d_sae']
D_MODEL = checkpoint['config']['d_in']
state_dict = checkpoint["model_state_dict"]
mean = state_dict.get("mean", None)

# %%
sae = TopKSAE(d_in=D_MODEL, d_sae=D_SAE, k=K_SAE_CFG, mean=mean).to("cuda")
sae.load_state_dict(checkpoint["model_state_dict"])
sae.eval()
# Out:
# TopKSAE()

# %%
# activations, labels = compute_sae_activations_batched(
#     hooked_model=hooked_model, sae=sae, tokenizer=tokenizer,
#     dataset=full_test, layer_idx=BEST_LAYER, max_samples=2000, batch_size=32, device="cuda", use_eval_prefix=True
# )
# np.save(SAE_DIR / "test_activations_formatted.npy", activations)
# np.save(SAE_DIR / "test_labels_formatted.npy", labels)
# Out:
# Вычисление активаций SAE (batch): 100%|██████████| 63/63 [01:03<00:00,  1.01s/it]

# %%
activations = np.load(SAE_DIR / "test_activations_formatted.npy")
labels = np.load(SAE_DIR / "test_labels_formatted.npy")
llm_preds = torch.load(BASELINE_CACHE_DIR / "test_acts_preds.pt", map_location="cpu", weights_only=False)["preds"].numpy()
print(f"Активации загружены: {activations.shape}, Метки: {labels.shape}")
# Out:
# Активации загружены: (2000, 16384), Метки: (2000,)

# %%
sparsity_per_feature = np.mean(activations != 0, axis=0)
dead = np.sum(sparsity_per_feature < 1e-6)
print(f"Dead features: {dead}/{D_SAE} ({100*dead/D_SAE:.1f}%)")
# Out:
# Dead features: 15857/16384 (96.8%)

# %% [markdown]
# # Ранжирование признаков и генерация правил

# %%
# активации вычислены с eval_prefix
eval_prefix = "{theory} {assertion} The assertion is"
def format_text_for_logic(item):
    if "theory" in item and "assertion" in item:
        return eval_prefix.format(theory=item["theory"], assertion=item["assertion"])
    return item.get("text", "")

# %%
dataset_texts_formatted = [format_text_for_logic(full_test[i]) for i in range(len(labels))]

# %%
# разделение train/test для генерации и оценки правил (контроль data leakage)
rng = np.random.default_rng(42)
indices = rng.permutation(len(activations))
n = len(activations)
split = n // 2

act_tr, act_te = activations[indices[:split]], activations[indices[split:]]
labels_tr, labels_te = labels[indices[:split]], labels[indices[split:]]
llm_tr, llm_te = llm_preds[indices[:split]], llm_preds[indices[split:]]
texts_tr = [dataset_texts_formatted[i] for i in indices[:split]]

# %%
# Предварительное ранжирование и генерация правил (строго на train)
top_feat, corr_label, corr_logic, combined = rank_features_by_logic(act_tr, llm_tr, texts_tr)

# %%
for i, idx in enumerate(top_feat[:10]):
    print(f"  {i}. Feature #{idx}: corr(llm)={corr_label[idx]:+.3f}, corr(logic)={corr_logic[idx]:+.3f}")

rules_candidates = generate_threshold_rules(act_tr, llm_tr, corr_label, top_feat, top_k=CANDIDATE_POOL_K)
# Out:
#   0. Feature #14255: corr(llm)=+0.881, corr(logic)=-0.105
#   1. Feature #13836: corr(llm)=+0.577, corr(logic)=-0.156
#   2. Feature #1757: corr(llm)=+0.907, corr(logic)=-0.098
#   3. Feature #13166: corr(llm)=+0.790, corr(logic)=-0.112
#   4. Feature #13630: corr(llm)=+0.786, corr(logic)=-0.112
#   5. Feature #8297: corr(llm)=-0.860, corr(logic)=+0.101
#   6. Feature #12428: corr(llm)=+0.905, corr(logic)=-0.094
#   7. Feature #9700: corr(llm)=+0.726, corr(logic)=-0.116
#   8. Feature #6661: corr(llm)=+0.771, corr(logic)=-0.109
#   9. Feature #3893: corr(llm)=+0.633, corr(logic)=-0.133

# %% [markdown]
# # Построение моделей на правилах

# %% [markdown]
# ## SAE + DT (сравнение с baseline)

# %%
sae_dt_results = []
for k in K_CANDIDATES:
    fid, acc, dt_mod = compute_dt_fidelity(act_te, act_tr, llm_te, llm_tr, labels_te, corr_label, k=k, max_depth=MAX_DEPTH)
    sae_dt_results.append({"K": k, "fidelity": round(fid, 4), "accuracy": round(acc, 4), "model": dt_mod})
    print(f"SAE+DT | K={k:4d} | Fidelity vs LLM: {fid:.4f} | Accuracy vs GT: {acc:.4f}")
# Out:
# SAE+DT | K=  50 | Fidelity vs LLM: 1.0000 | Accuracy vs GT: 0.9990
# SAE+DT | K= 100 | Fidelity vs LLM: 0.9990 | Accuracy vs GT: 0.9980
# SAE+DT | K= 200 | Fidelity vs LLM: 1.0000 | Accuracy vs GT: 0.9990
# SAE+DT | K= 500 | Fidelity vs LLM: 1.0000 | Accuracy vs GT: 0.9990

# %% [markdown]
# ## Best Single Rule (оценка на test)

# %%
best_fid, best_rule_info = compute_best_single_rule(
    act_te, act_tr, llm_te, llm_tr, corr_label, top_k_search=200
)

fid = best_rule_info["feature_id"]
thr = best_rule_info["threshold"]
corr = best_rule_info["corr"]

preds_gt = (act_te[:, fid] > thr).astype(int)
if corr <= 0:
    preds_gt = 1 - preds_gt
best_acc = float(np.mean(preds_gt == labels_te))

print(f"Fidelity vs LLM: {best_fid:.4f} | Accuracy vs GT: {best_acc:.4f} | Feature #{fid}")
# Out:
# Fidelity vs LLM: 1.0000 | Accuracy vs GT: 0.9990 | Feature #48

# %% [markdown]
# ## Пороговые правила SAE (Union Coverage (оценка на test))

# %%
union_cov_llm, num_passed_rules = compute_union_coverage(
    act_te, act_tr, llm_te, llm_tr, corr_label, k=CANDIDATE_POOL_K, min_cov=0.01, min_acc=0.60
)
print(f"Прошло фильтр: {num_passed_rules} из {CANDIDATE_POOL_K}")
print(f"Union Coverage vs LLM: {union_cov_llm:.4f}")
# Out:
# Прошло фильтр: 32 из 50
# Union Coverage vs LLM: 1.0000

# %% [markdown]
# # Результаты

# %%
combined_rows = []

# %%
baseline_json_path = BASELINE_DIR / "comparison_table_clean.json"
with open(baseline_json_path, "r", encoding="utf-8") as f:
    baseline_rows = json.load(f)
combined_rows.extend(baseline_rows)

# %%
for res in sae_dt_results:
    combined_rows.append({
        "Method": "SAE", "Mode": "Decision Tree", "K": res["K"],
        "Fidelity_vs_LLM": res["fidelity"], "Accuracy_vs_GT": res["accuracy"],
        "Union_Coverage_vs_LLM": round(union_cov_llm, 4),
        "Notes": "Единая модель на латентах"
    })

# %%
combined_rows.append({
    "Method": "SAE", "Mode": "Best Single Rule", "K": None,
    "Fidelity_vs_LLM": round(best_fid, 4), "Accuracy_vs_GT": round(best_acc, 4),
    "Union_Coverage_vs_LLM": None,
    "Notes": "Одно пороговое правило"
})

# %%
combined_rows.append({
    "Method": "SAE", "Mode": "Rules (Union)", "K": CANDIDATE_POOL_K,
    "Fidelity_vs_LLM": None, "Accuracy_vs_GT": None,
    "Union_Coverage_vs_LLM": round(union_cov_llm, 4),
    "Notes": f"OR-ансамбль: {num_passed_rules} правил прошло фильтр"
})

# %%
df_combined = pd.DataFrame(combined_rows)

# %%
df_combined.to_csv(BASELINE_DIR / "final_comparison_table_centered.csv", index=False)
df_combined.to_json(BASELINE_DIR / "final_comparison_table_centered.json", orient="records", indent=2)

# %%
df_combined
# Out:
#                  Method              Mode      K  Fidelity_vs_LLM  \
# 0   Gradient Importance     Decision Tree   50.0           0.9125
# 1   Gradient Importance     Decision Tree  100.0           0.9830
# 2   Gradient Importance     Decision Tree  200.0           0.9395
# 3   Gradient Importance     Decision Tree  500.0           0.6985
# 4   Gradient Importance  Best Single Rule    NaN           0.5110
# 5         SHAP (Linear)     Decision Tree   50.0           0.9895
# 6         SHAP (Linear)     Decision Tree  100.0           0.8625
# 7         SHAP (Linear)     Decision Tree  200.0           0.9895
# 8         SHAP (Linear)     Decision Tree  500.0           0.9895
# 9         SHAP (Linear)  Best Single Rule    NaN           0.9605
# 10                  SAE     Decision Tree   50.0           1.0000
# 11                  SAE     Decision Tree  100.0           0.9990
# 12                  SAE     Decision Tree  200.0           1.0000
# 13                  SAE     Decision Tree  500.0           1.0000
# 14                  SAE  Best Single Rule    NaN           1.0000
# 15                  SAE     Rules (Union)   50.0              NaN
#
#     Accuracy_vs_GT  Union_Coverage_vs_LLM  \
# 0           0.9125                    1.0
# 1           0.9830                    1.0
# 2           0.9405                    1.0
# 3           0.6995                    1.0
# 4           0.5100                    NaN
# 5           0.9885                    1.0
# 6           0.8635                    1.0
# 7           0.9885                    1.0
# 8           0.9885                    1.0
# 9           0.9595                    NaN
# 10          0.9990                    1.0
# 11          0.9980                    1.0
# 12          0.9990                    1.0
# 13          0.9990                    1.0
# 14          0.9990                    NaN
# 15             NaN                    1.0
#
#                                    Notes
# 0              Единая суррогатная модель
# 1              Единая суррогатная модель
# 2              Единая суррогатная модель
# 3              Единая суррогатная модель
# 4                 Одно пороговое правило
# 5              Единая суррогатная модель
# 6              Единая суррогатная модель
# 7              Единая суррогатная модель
# 8              Единая суррогатная модель
# 9                 Одно пороговое правило
# 10             Единая модель на латентах
# 11             Единая модель на латентах
# 12             Единая модель на латентах
# 13             Единая модель на латентах
# 14                Одно пороговое правило
# 15  OR-ансамбль: 32 правил прошло фильтр

# %% [markdown]
# # Визуализации

# %%
passed_rules_df = pd.DataFrame(rules_candidates)
passed_rules_df = passed_rules_df[(passed_rules_df["coverage"] >= 0.01) & (passed_rules_df["rule_accuracy"] >= 0.60)]

passed_rules_df["utility_score"] = passed_rules_df["rule_accuracy"] * passed_rules_df["coverage"]
passed_rules_df = passed_rules_df.sort_values("utility_score", ascending=False).reset_index(drop=True)

styled_df = passed_rules_df.style.background_gradient(
    subset=['coverage', 'rule_accuracy', 'utility_score'],
    cmap='YlOrRd', vmin=0, vmax=1)\
    .format(precision=3)\
    .set_caption(f"Правила, прошедшие фильтрацию ({len(passed_rules_df)} шт., отсортированы по полезности = acc x cov)")
display(styled_df)
# Out:
# <style type="text/css">
# #T_8954a_row0_col4, #T_8954a_row2_col4 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_8954a_row0_col5, #T_8954a_row0_col6, #T_8954a_row1_col5, #T_8954a_row1_col6, #T_8954a_row2_col5, #T_8954a_row2_col6 {
#   background-color: #fd8e3c;
#   color: #f1f1f1;
# }
# #T_8954a_row1_col4, #T_8954a_row3_col4 {
#   background-color: #820026;
#   color: #f1f1f1;
# }
# #T_8954a_row3_col5 {
#   background-color: #fd8f3d;
#   color: #f1f1f1;
# }
# #T_8954a_row3_col6 {
#   background-color: #fd903d;
#   color: #000000;
# }
# #T_8954a_row4_col4 {
#   background-color: #8b0026;
#   color: #f1f1f1;
# }
# #T_8954a_row4_col5 {
#   background-color: #fd913e;
#   color: #000000;
# }
# #T_8954a_row4_col6, #T_8954a_row6_col5 {
#   background-color: #fd953f;
#   color: #000000;
# }
# #T_8954a_row5_col4 {
#   background-color: #930026;
#   color: #f1f1f1;
# }
# #T_8954a_row5_col5 {
#   background-color: #fd933f;
#   color: #000000;
# }
# #T_8954a_row5_col6, #T_8954a_row6_col6 {
#   background-color: #fd9941;
#   color: #000000;
# }
# #T_8954a_row6_col4 {
#   background-color: #8f0026;
#   color: #f1f1f1;
# }
# #T_8954a_row7_col4 {
#   background-color: #9f0026;
#   color: #f1f1f1;
# }
# #T_8954a_row7_col5 {
#   background-color: #fd923e;
#   color: #000000;
# }
# #T_8954a_row7_col6, #T_8954a_row8_col5 {
#   background-color: #fd9c42;
#   color: #000000;
# }
# #T_8954a_row8_col4, #T_8954a_row9_col4 {
#   background-color: #990026;
#   color: #f1f1f1;
# }
# #T_8954a_row8_col6 {
#   background-color: #fea245;
#   color: #000000;
# }
# #T_8954a_row9_col5 {
#   background-color: #fd9d43;
#   color: #000000;
# }
# #T_8954a_row9_col6 {
#   background-color: #fea446;
#   color: #000000;
# }
# #T_8954a_row10_col4 {
#   background-color: #a80026;
#   color: #f1f1f1;
# }
# #T_8954a_row10_col5, #T_8954a_row12_col5 {
#   background-color: #fea546;
#   color: #000000;
# }
# #T_8954a_row10_col6 {
#   background-color: #feaf4b;
#   color: #000000;
# }
# #T_8954a_row11_col4 {
#   background-color: #c20325;
#   color: #f1f1f1;
# }
# #T_8954a_row11_col5 {
#   background-color: #fea948;
#   color: #000000;
# }
# #T_8954a_row11_col6, #T_8954a_row12_col6 {
#   background-color: #febb56;
#   color: #000000;
# }
# #T_8954a_row12_col4 {
#   background-color: #cb0a22;
#   color: #f1f1f1;
# }
# #T_8954a_row13_col4 {
#   background-color: #bb0026;
#   color: #f1f1f1;
# }
# #T_8954a_row13_col5 {
#   background-color: #feb04b;
#   color: #000000;
# }
# #T_8954a_row13_col6, #T_8954a_row15_col5 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_8954a_row14_col4 {
#   background-color: #d51020;
#   color: #f1f1f1;
# }
# #T_8954a_row14_col5 {
#   background-color: #feb54f;
#   color: #000000;
# }
# #T_8954a_row14_col6 {
#   background-color: #fecc68;
#   color: #000000;
# }
# #T_8954a_row15_col4 {
#   background-color: #ca0923;
#   color: #f1f1f1;
# }
# #T_8954a_row15_col6, #T_8954a_row19_col5, #T_8954a_row20_col5 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_8954a_row16_col4 {
#   background-color: #d00d21;
#   color: #f1f1f1;
# }
# #T_8954a_row16_col5 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_8954a_row16_col6 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_8954a_row17_col4 {
#   background-color: #d7121f;
#   color: #f1f1f1;
# }
# #T_8954a_row17_col5 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_8954a_row17_col6, #T_8954a_row18_col6 {
#   background-color: #fedd7f;
#   color: #000000;
# }
# #T_8954a_row18_col4 {
#   background-color: #d9131f;
#   color: #f1f1f1;
# }
# #T_8954a_row18_col5 {
#   background-color: #fecf6b;
#   color: #000000;
# }
# #T_8954a_row19_col4 {
#   background-color: #da141e;
#   color: #f1f1f1;
# }
# #T_8954a_row19_col6 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_8954a_row20_col4, #T_8954a_row21_col4 {
#   background-color: #df171d;
#   color: #f1f1f1;
# }
# #T_8954a_row20_col6 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_8954a_row21_col5 {
#   background-color: #fed572;
#   color: #000000;
# }
# #T_8954a_row21_col6 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_8954a_row22_col4 {
#   background-color: #e0181d;
#   color: #f1f1f1;
# }
# #T_8954a_row22_col5 {
#   background-color: #fed673;
#   color: #000000;
# }
# #T_8954a_row22_col6 {
#   background-color: #fee288;
#   color: #000000;
# }
# #T_8954a_row23_col4 {
#   background-color: #e6211e;
#   color: #f1f1f1;
# }
# #T_8954a_row23_col5 {
#   background-color: #fedb7b;
#   color: #000000;
# }
# #T_8954a_row23_col6 {
#   background-color: #ffe590;
#   color: #000000;
# }
# #T_8954a_row24_col4, #T_8954a_row25_col4 {
#   background-color: #e7231e;
#   color: #f1f1f1;
# }
# #T_8954a_row24_col5, #T_8954a_row25_col5 {
#   background-color: #fedc7c;
#   color: #000000;
# }
# #T_8954a_row24_col6, #T_8954a_row25_col6 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_8954a_row26_col4 {
#   background-color: #ef3323;
#   color: #f1f1f1;
# }
# #T_8954a_row26_col5 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_8954a_row26_col6 {
#   background-color: #ffec9f;
#   color: #000000;
# }
# #T_8954a_row27_col4 {
#   background-color: #f03523;
#   color: #f1f1f1;
# }
# #T_8954a_row27_col5 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_8954a_row27_col6 {
#   background-color: #ffeda1;
#   color: #000000;
# }
# #T_8954a_row28_col4, #T_8954a_row30_col4, #T_8954a_row31_col4 {
#   background-color: #f74327;
#   color: #f1f1f1;
# }
# #T_8954a_row28_col5 {
#   background-color: #ffe895;
#   color: #000000;
# }
# #T_8954a_row28_col6, #T_8954a_row29_col6 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_8954a_row29_col4 {
#   background-color: #f64227;
#   color: #f1f1f1;
# }
# #T_8954a_row29_col5 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_8954a_row30_col5, #T_8954a_row31_col5 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_8954a_row30_col6, #T_8954a_row31_col6 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# </style>
# <table id="T_8954a">
#   <caption>Правила, прошедшие фильтрацию (32 шт., отсортированы по полезности = acc x cov)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8954a_level0_col0" class="col_heading level0 col0" >feature_id</th>
#       <th id="T_8954a_level0_col1" class="col_heading level0 col1" >threshold</th>
#       <th id="T_8954a_level0_col2" class="col_heading level0 col2" >corr_with_label</th>
#       <th id="T_8954a_level0_col3" class="col_heading level0 col3" >predicted_class</th>
#       <th id="T_8954a_level0_col4" class="col_heading level0 col4" >rule_accuracy</th>
#       <th id="T_8954a_level0_col5" class="col_heading level0 col5" >coverage</th>
#       <th id="T_8954a_level0_col6" class="col_heading level0 col6" >utility_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8954a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8954a_row0_col0" class="data row0 col0" >48</td>
#       <td id="T_8954a_row0_col1" class="data row0 col1" >10.420</td>
#       <td id="T_8954a_row0_col2" class="data row0 col2" >-0.992</td>
#       <td id="T_8954a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8954a_row0_col4" class="data row0 col4" >0.999</td>
#       <td id="T_8954a_row0_col5" class="data row0 col5" >0.499</td>
#       <td id="T_8954a_row0_col6" class="data row0 col6" >0.499</td>
#     </tr>
#     <tr>
#       <th id="T_8954a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8954a_row1_col0" class="data row1 col0" >10304</td>
#       <td id="T_8954a_row1_col1" class="data row1 col1" >11.556</td>
#       <td id="T_8954a_row1_col2" class="data row1 col2" >-0.973</td>
#       <td id="T_8954a_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_8954a_row1_col4" class="data row1 col4" >0.995</td>
#       <td id="T_8954a_row1_col5" class="data row1 col5" >0.499</td>
#       <td id="T_8954a_row1_col6" class="data row1 col6" >0.497</td>
#     </tr>
#     <tr>
#       <th id="T_8954a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8954a_row2_col0" class="data row2 col0" >15349</td>
#       <td id="T_8954a_row2_col1" class="data row2 col1" >13.660</td>
#       <td id="T_8954a_row2_col2" class="data row2 col2" >-0.966</td>
#       <td id="T_8954a_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_8954a_row2_col4" class="data row2 col4" >0.999</td>
#       <td id="T_8954a_row2_col5" class="data row2 col5" >0.497</td>
#       <td id="T_8954a_row2_col6" class="d

# %%
feature_ids = [r for r in passed_rules_df['feature_id']]

# %%
fig, ax = plt.subplots(figsize=(7, 5))
top30 = top_feat[:30]  # top_feat из rank_features_by_logic

sc = ax.scatter(corr_label[top30], corr_logic[top30],
                c=combined[top30], cmap='viridis', s=40, edgecolors='k', alpha=0.8)

ax.set_xlabel('Корреляция с предсказаниями LLM')
ax.set_ylabel('Корреляция с логическими операторами')
ax.set_title('Топ-30 латентов SAE: корреляционный профиль (train)')
ax.axhline(0, color='gray', linestyle='--', alpha=0.5)
ax.axvline(0, color='gray', linestyle='--', alpha=0.5)

# Подписываем латенты, которые прошли фильтрацию правил
passed_fids = {r["feature_id"] for r in rules_candidates
                if r["coverage"] >= 0.01 and r["rule_accuracy"] >= 0.60}
# for fid in feature_ids[:5]:
#     ax.annotate(f'#{fid}', (corr_label[fid], corr_logic[fid]), fontsize=9)

cbar = fig.colorbar(sc, ax=ax, label='|corr_llm × corr_logic|')
ax.grid(True, alpha=0.2)
plt.tight_layout()
plt.show()

# %%
dt_k200 = next((r["model"] for r in sae_dt_results if r["K"] == 200), None)
if dt_k200:
    feat_ids = np.argsort(np.abs(corr_label))[::-1][:200]
    fig, ax = plt.subplots(figsize=(14, 5))
    plot_tree(dt_k200, feature_names=[f"L_{fid}" for fid in feat_ids],
              class_names=["False", "True"], filled=True, rounded=True,
              impurity=False, proportion=True, fontsize=10, ax=ax)
    ax.set_title("Decision Tree на латентах SAE (K=200, max_depth=3)")
    plt.tight_layout()
    plt.show()

# %%
# Кривая насыщения и RuleFit (test)
# Сортировка правил для кривой по покрытию (на train), оценка на test
rules_sorted = sorted(rules_candidates, key=lambda r: r["coverage"], reverse=True)
passed_sorted = [r for r in rules_sorted if r["coverage"] >= 0.01 and r["rule_accuracy"] >= 0.60]

# %%
coverages = []
explained = np.zeros(len(act_te), dtype=bool)
for i, r in enumerate(passed_sorted, 1):
    preds = (act_te[:, r["feature_id"]] > r["threshold"]).astype(int)
    if r["corr_with_label"] <= 0:
        preds = 1 - preds
    explained |= (preds == llm_te)
    coverages.append((i, float(np.mean(explained))))

sat_95 = next((k for k, cov in coverages if cov >= 0.95), None)
print(f"95% покрытие на test достигается при {sat_95} правилах")
# Out:
# 95% покрытие на test достигается при 1 правилах

# %%
coverages[:3]
# Out:
# [(1, 1.0), (2, 1.0), (3, 1.0)]

# %%
x, y = zip(*coverages)
plt.figure(figsize=(6, 4))
plt.plot(x, y, marker='o')
# plt.axhline(0.95, color='gray', linestyle='--', alpha=0.5)
plt.xlabel("Количество правил")
plt.ylabel("Union Coverage")
plt.title("Насыщение покрытия: SAE-латенты")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
feat_ids_rf = [r["feature_id"] for r in passed_sorted]
rf = RuleFit(tree_size=4, sample_fract=0.7, max_rules=2000, memory_par=0.5,
                rfmode="classify", lin_trim_quantile=0.025, lin_standardise=True, random_state=42)
rf.fit(act_tr[:, feat_ids_rf], llm_tr)
rf_preds = rf.predict(act_te[:, feat_ids_rf])
print(f"RuleFit | Fidelity vs LLM: {np.mean(rf_preds == llm_te):.4f} | Accuracy vs GT: {np.mean(rf_preds == labels_te):.4f}")

rf_rules = rf.get_rules()
rf_active = rf_rules[rf_rules.coef != 0].sort_values("support", ascending=False)
display(rf_active[["rule", "support", "coef"]].head(10).round(3))
# Out:
# RuleFit | Fidelity vs LLM: 1.0000 | Accuracy vs GT: 0.9990
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1780: FutureWarning: The default value for l1_ratios will change from None to (0.0,) in version 1.10. From version 1.10 onwards, only array-like with values in [0, 1] will be allowed, None will be forbidden. To avoid this warning, explicitly set a value, e.g. l1_ratios=(0,).
#   warnings.warn(
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1811: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratios' instead. Use l1_ratios=(0,) instead of penalty='l2'  and l1_ratios=(1,) instead of penalty='l1'.
#   warnings.warn(
# c:\MyPythonProjects\mephi_diss\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1823: FutureWarning: The fitted attributes of LogisticRegressionCV will be simplified in scikit-learn 1.10 to remove redundancy. Set`use_legacy_attributes=False` to enable the new behavior now, or set it to `True` to silence this warning during the transition period while keeping the deprecated behavior for the time being. The default value of use_legacy_attributes will change from True to False in scikit-learn 1.10. See the docstring of LogisticRegressionCV for more details.
#   warnings.warn(
#                                                   rule  support   coef
# 4                                            feature_4    1.000 -0.015
# 19                                          feature_19    1.000  0.001
# 23                                          feature_23    1.000  0.004
# 5                                            feature_5    1.000  0.000
# 43                     feature_11 <= 18.31292724609375    0.893 -0.203
# 56                     feature_11 <= 18.32893180847168    0.879 -0.722
# 54   feature_3 > 6.981830596923828 & feature_0 > 7....    0.554 -0.265
# 78                     feature_0 <= 16.241826057434082    0.547  1.197
# 162                   feature_27 <= 27.634645462036133    0.543  0.455
# 45                     feature_17 <= 45.24664306640625    0.536  0.244

# %%
feature_to_latent = {f"feature_{i}": f"Latent_{feat_ids_rf[i]}" for i in range(len(feat_ids_rf))}

# Функция для замены всех вхождений feature_N в строке правила
def replace_features(rule_str, feature_to_latent):
    # Сортируем ключи по длине строки в обратном порядке
    for feat in sorted(feature_to_latent.keys(), key=len, reverse=True):
        rule_str = rule_str.replace(feat, feature_to_latent[feat])
    return rule_str

# Применяем к столбцу rule
rf_active["rule"] = rf_active["rule"].apply(
    lambda r: replace_features(r, feature_to_latent)
)

rf_active["rule_short"] = rf_active["rule"].str.replace(
    r"(\d+\.\d{4})\d*", r"\1", regex=True
)

rf_active.head(10)
# Out:
#                                                   rule    type      coef  \
# 4                                          Latent_8140  linear -0.014747
# 19                                         Latent_2321  linear  0.000664
# 23                                        Latent_13823  linear  0.004484
# 5                                          Latent_5315  linear  0.000349
# 43                    Latent_6378 <= 18.31292724609375    rule -0.202699
# 56                    Latent_6378 <= 18.32893180847168    rule -0.721776
# 54   Latent_6640 > 6.981830596923828 & Latent_48 > ...    rule -0.265063
# 78                     Latent_48 <= 16.241826057434082    rule  1.196958
# 162                  Latent_3417 <= 27.634645462036133    rule  0.455388
# 45                   Latent_13663 <= 45.24664306640625    rule  0.243623
#
#       support  importance                                 rule_short
# 4    1.000000    0.192934                                Latent_8140
# 19   1.000000    0.007191                                Latent_2321
# 23   1.000000    0.065721                               Latent_13823
# 5    1.000000    0.003481                                Latent_5315
# 43   0.892734    0.062726                     Latent_6378 <= 18.3129
# 56   0.878893    0.235481                     Latent_6378 <= 18.3289
# 54   0.553633    0.131767  Latent_6640 > 6.9818 & Latent_48 > 7.6665
# 78   0.546713    0.595861                       Latent_48 <= 16.2418
# 162  0.543253    0.226841                     Latent_3417 <= 27.6346
# 45   0.536332    0.121489                    Latent_13663 <= 45.2466

# %%
fid_map = {f"feature_{i}": f"Latent_{feat_ids_rf[i]}" for i in range(len(feat_ids_rf))}
rf_active = rf_active.rename(index=fid_map)

is_linear = ~rf_active["rule"].str.contains("<=") & ~rf_active["rule"].str.contains(" and ")
rf_tree_rules = rf_active[~is_linear].sort_values("support", ascending=False).head(10)
rf_lin_rules = rf_active[is_linear].sort_values(by="coef", key=lambda x: x.abs(), ascending=False).head(5)

# %%
print("Топ-10 нелинейных правил (основной сигнал):")
display(rf_tree_rules[["rule_short", "support", "coef"]].round(3))
# Out:
# Топ-10 нелинейных правил (основной сигнал):
#                   rule_short  support   coef
# 43    Latent_6378 <= 18.3129    0.893 -0.203
# 56    Latent_6378 <= 18.3289    0.879 -0.722
# 78      Latent_48 <= 16.2418    0.547  1.197
# 162   Latent_3417 <= 27.6346    0.543  0.455
# 45   Latent_13663 <= 45.2466    0.536  0.244
# 49    Latent_15349 <= 7.5236    0.533  0.525
# 153     Latent_48 <= 15.5041    0.533  0.387
# 67    Latent_3417 <= 29.9699    0.529  0.511
# 36    Latent_14292 <= 8.6464    0.519 -0.099
# 132      Latent_48 <= 8.2238    0.519  0.046

# %%
print("Топ-5 линейных членов (регуляризованы к ~0):")
display(rf_lin_rules[["rule_short", "support", "coef"]].round(3))
# Out:
# Топ-5 линейных членов (регуляризованы к ~0):
#                                          rule_short  support   coef
# 82                              Latent_48 > 15.5041    0.467 -1.025
# 39                            Latent_3417 > 27.6346    0.457 -1.001
# 41         Latent_48 > 7.8376 & Latent_48 > 15.8556    0.516 -0.832
# 126                              Latent_48 > 7.8376    0.498 -0.814
# 111  Latent_15349 > 8.5765 & Latent_13663 > 45.5591    0.505 -0.602

# %% [markdown]
# # Семантическая аннотация и атрибуции

# %%
feat_ids_annot = list({int(best_rule_info["feature_id"])} | set(np.argsort(np.abs(corr_label))[::-1][:3].tolist()))
annotations = extract_semantic_annotations(activations, full_test, tokenizer, feat_ids_annot[:3], top_k=10)
for ann in annotations:
    print(f"Латент #{ann['feature_id']} | Топ-токены: {[t[0] for t in ann['top_tokens'][:10]]}")
# Out:
# Латент #48 | Топ-токены: ['the', '.', 'is', 'lion', 'cat', 'if', 'then', 'dog', 'and', 'eats']
# Латент #6640 | Топ-токены: ['the', '.', 'is', 'mouse', 'tiger', 'rabbit', 'if', 'then', 'cat', 'eats']
# Латент #8095 | Топ-токены: ['.', 'is', 'the', 'not', 'if', 'then', 'tiger', 'cow', 'are', 'dave']

# %%
def compare_attributions(latent_idx, example_idx, steps_ig=50):
    text = full_test[example_idx]["text"]
    true_label = bool(full_test[example_idx]["label"])
    tokens_tensor = hooked_model.to_tokens([text], prepend_bos=True).to("cuda")
    raw_tokens = tokenizer.convert_ids_to_tokens(tokens_tensor[0])
    tokens = [t.replace('Ġ', '') if t != 'Ġ' else t for t in raw_tokens]

    with torch.no_grad():
        _, cache = hooked_model.run_with_cache(tokens_tensor, names_filter=lambda n: f"blocks.{BEST_LAYER}.attn.hook_pattern" in n)
    attn_scores = cache[f"blocks.{BEST_LAYER}.attn.hook_pattern"][0, :, -1, :].mean(dim=0).cpu().numpy()

    true_id = int(tokenizer.encode("True", add_special_tokens=False)[-1])
    embeds = hooked_model.embed(tokens_tensor).clone().detach().requires_grad_(True)

    def embed_hook(act, hook):
        return embeds

    logits_sal = hooked_model.run_with_hooks(tokens_tensor, fwd_hooks=[("hook_embed", embed_hook)])
    logits_sal[0, -1, true_id].float().backward()
    saliency_scores = np.linalg.norm(embeds.grad.cpu().float().numpy()[0], axis=-1)

    _, ig_scores = integrated_gradients_latent(hooked_model, sae, tokenizer, text, BEST_LAYER, latent_idx, steps_ig)

    min_len = min(len(tokens), len(attn_scores), len(saliency_scores), len(ig_scores))
    tokens, attn_scores, saliency_scores, ig_scores = (arr[:min_len] for arr in [tokens, attn_scores, saliency_scores, ig_scores])

    with torch.no_grad():
        logits = hooked_model(tokens_tensor)
    false_id = int(tokenizer.encode("False", add_special_tokens=False)[-1])
    pred_str = "True" if logits[0, -1, true_id] > logits[0, -1, false_id] else "False"
    match_str = "совпадает" if (pred_str == "True") == true_label else "не совпадает"
    label_str = "True" if true_label else "False"

    print(f"Example #{example_idx} | Latent #{latent_idx} | GT: {label_str} | Model: {pred_str} ({match_str})")
    visualize_token_attributions(tokens, attn_scores, f"Attention (Layer {BEST_LAYER})", "YlOrRd", False)
    visualize_token_attributions(tokens, saliency_scores, "Gradient Saliency", "YlOrRd", False)
    visualize_token_attributions(tokens, ig_scores, f"IG (Latent #{latent_idx})", "coolwarm", True)

# %% [markdown]
# # Пример 1

# %%
fid = best_rule_info["feature_id"]
top_idx = np.argsort(activations[:, fid])[::-1][0]
compare_attributions(latent_idx=fid, example_idx=int(top_idx))
# Out:
# IG для латента 48: 100%|██████████| 50/50 [01:01<00:00,  1.23s/it]
# Example #1708 | Latent #48 | GT: False | Model: False (совпадает)
# <div style='line-height:1.5; padding:5px; background:#fff; border:1px solid #eee; border-radius:3px; margin-bottom:15px;'><div style='font-weight:bold; margin-bottom:5px; font-size:12px;'>Attention (Layer 34)</div><span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;"><|endoftext|></span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(254, 210, 111, 0.56); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(254, 226, 138, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(234, 41, 32, 0.83); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">green</span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(158, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 248, 187, 0.43); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(255, 252, 197, 0.41); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">red</span> <span style="background-color:rgba(215, 18, 31, 0.87); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(220, 21, 29, 0.86); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 249, 190, 0.43); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(255, 249, 190, 0.43); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(252, 120, 54, 0.72); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">young</span> <span style="background-color:rgba(239, 52, 35, 0.81); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(248, 70, 39, 0.79); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 249, 190, 0.42); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(252, 124, 55, 0.72); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">sees</span> <span style="background-color:rgba(240, 54, 35, 0.81); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">the</span> <span style="background-color:rgba(193, 3, 36, 0.91); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">lion</span> <span style="background-color:rgba(253, 156, 66, 0.67); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(231, 36, 30, 0.83); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(254, 231, 149, 0.50); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">lion</span> <span style="background-color:rgba(253, 158, 67, 0.66); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">ea ...
# <div style='line-height:1.5; padding:5px; background:#fff; border:1px solid #eee; border-radius:3px; margin-bottom:15px;'><div style='font-weight:bold; margin-bottom:5px; font-size:12px;'>Gradient Saliency</div><span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;"><|endoftext|></span> <span style="background-color:rgba(254, 187, 86, 0.61); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(211, 15, 32, 0.88); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(254, 203, 103, 0.58); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(252, 84, 43, 0.77); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">green</span> <span style="background-color:rgba(254, 224, 133, 0.52); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(254, 228, 142, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(254, 188, 87, 0.60); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(254, 224, 133, 0.52); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 208, 108, 0.57); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">red</span> <span style="background-color:rgba(254, 233, 151, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(254, 233, 153, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(254, 218, 121, 0.54); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(254, 228, 142, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 186, 84, 0.61); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">young</span> <span style="background-color:rgba(254, 231, 149, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(254, 234, 154, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(254, 223, 132, 0.53); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(253, 161, 68, 0.66); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">sees</span> <span style="background-color:rgba(255, 240, 169, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">the</span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">lion</span> <span style="background-color:rgba(254, 226, 138, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(254, 220, 125, 0.54); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(135, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">lion</span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:m ...
# <div style='line-height:1.5; padding:5px; background:#fff; border:1px solid #eee; border-radius:3px; margin-bottom:15px;'><div style='font-weight:bold; margin-bottom:5px; font-size:12px;'>IG (Latent #48)</div><span style="background-color:rgba(237, 132, 103, 0.76); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;"><|endoftext|></span> <span style="background-color:rgba(179, 3, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(205, 66, 58, 0.91); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(246, 189, 164, 0.58); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(247, 179, 151, 0.61); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">green</span> <span style="background-color:rgba(236, 209, 195, 0.48); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(236, 210, 196, 0.48); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(239, 205, 187, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(231, 214, 204, 0.45); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(237, 208, 193, 0.48); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">red</span> <span style="background-color:rgba(231, 214, 205, 0.45); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(232, 213, 202, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(239, 205, 187, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(231, 214, 204, 0.45); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(237, 208, 193, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">young</span> <span style="background-color:rgba(231, 214, 204, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(233, 212, 201, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(241, 203, 184, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(238, 207, 190, 0.50); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">sees</span> <span style="background-color:rgba(234, 211, 199, 0.47); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">the</span> <span style="background-color:rgba(245, 193, 168, 0.56); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">lion</span> <span style="background-color:rgba(233, 212, 201, 0.47); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(236, 209, 195, 0.48); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(245, 192, 167, 0.56); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">lion</span> <span style="background-color:rgba(242, 201, 181, 0.53); color:black; padding:2px 0px; margin:1px; border-radius:3px;  ...

# %%
fid = best_rule_info["feature_id"]
top_idx = np.argsort(activations[:, fid])[::-1][6]
compare_attributions(latent_idx=fid, example_idx=int(top_idx))
# Out:
# IG для латента 48: 100%|██████████| 50/50 [01:01<00:00,  1.22s/it]
# Example #1411 | Latent #48 | GT: False | Model: True (не совпадает)
# <div style='line-height:1.5; padding:5px; background:#fff; border:1px solid #eee; border-radius:3px; margin-bottom:15px;'><div style='font-weight:bold; margin-bottom:5px; font-size:12px;'>Attention (Layer 34)</div><span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;"><|endoftext|></span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 244, 177, 0.44); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(254, 229, 144, 0.50); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">ch</span> <span style="background-color:rgba(255, 240, 169, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">ases</span> <span style="background-color:rgba(245, 63, 38, 0.79); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">the</span> <span style="background-color:rgba(252, 104, 49, 0.74); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">tiger</span> <span style="background-color:rgba(209, 13, 32, 0.88); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 247, 184, 0.43); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(255, 243, 175, 0.45); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 186, 84, 0.61); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">blue</span> <span style="background-color:rgba(252, 96, 47, 0.75); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 251, 194, 0.42); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(255, 251, 195, 0.42); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(255, 252, 198, 0.41); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">not</span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cold</span> <span style="background-color:rgba(253, 152, 64, 0.68); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(232, 37, 31, 0.83); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 251, 195, 0.42); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(255, 253, 199, 0.41); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 233, 153, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">green</span> <span style="background-color:rgba(254, 191, 90, 0.60); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(252, 102, 48, 0.75); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospa ...
# <div style='line-height:1.5; padding:5px; background:#fff; border:1px solid #eee; border-radius:3px; margin-bottom:15px;'><div style='font-weight:bold; margin-bottom:5px; font-size:12px;'>Gradient Saliency</div><span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;"><|endoftext|></span> <span style="background-color:rgba(254, 179, 78, 0.62); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(168, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(254, 191, 90, 0.60); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">ch</span> <span style="background-color:rgba(253, 165, 70, 0.65); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">ases</span> <span style="background-color:rgba(254, 227, 140, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">the</span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">tiger</span> <span style="background-color:rgba(254, 224, 133, 0.52); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(254, 228, 141, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(254, 205, 105, 0.57); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(254, 205, 105, 0.57); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(253, 160, 68, 0.66); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">blue</span> <span style="background-color:rgba(254, 230, 145, 0.50); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(254, 233, 151, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(254, 228, 141, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(254, 219, 122, 0.54); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 216, 117, 0.55); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">not</span> <span style="background-color:rgba(210, 14, 32, 0.88); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cold</span> <span style="background-color:rgba(255, 239, 165, 0.47); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(255, 239, 166, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(254, 236, 158, 0.48); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(254, 232, 150, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(228, 29, 28, 0.84); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">green</span> <span style="background-color:rgba(255, 239, 165, 0.47); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(255, 237, 161, 0.47); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family ...
# <div style='line-height:1.5; padding:5px; background:#fff; border:1px solid #eee; border-radius:3px; margin-bottom:15px;'><div style='font-weight:bold; margin-bottom:5px; font-size:12px;'>IG (Latent #48)</div><span style="background-color:rgba(194, 45, 49, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;"><|endoftext|></span> <span style="background-color:rgba(201, 59, 55, 0.93); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(206, 68, 60, 0.91); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(241, 142, 112, 0.73); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">ch</span> <span style="background-color:rgba(227, 108, 84, 0.82); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">ases</span> <span style="background-color:rgba(246, 188, 162, 0.58); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">the</span> <span style="background-color:rgba(246, 167, 137, 0.66); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">tiger</span> <span style="background-color:rgba(238, 207, 190, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(239, 206, 188, 0.50); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(246, 187, 160, 0.58); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(236, 209, 195, 0.48); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(243, 198, 176, 0.54); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">blue</span> <span style="background-color:rgba(237, 208, 193, 0.48); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(238, 207, 190, 0.50); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(246, 189, 164, 0.58); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(237, 207, 192, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(239, 206, 188, 0.50); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">not</span> <span style="background-color:rgba(246, 186, 159, 0.59); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cold</span> <span style="background-color:rgba(239, 205, 187, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(242, 201, 181, 0.53); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(247, 174, 145, 0.63); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">cat</span> <span style="background-color:rgba(241, 203, 184, 0.52); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(247, 174, 145, 0.63); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">green</span> <span style="background-color:rgba(241, 203, 184, 0.52); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(241, 203, 184, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; fon ...

# %%
feature_ids[1]
# Out:
# 10304

# %%
fid = feature_ids[1]
feat_ids_annot = list({fid} | set(np.argsort(np.abs(corr_label))[::-1][:3].tolist()))
annotations = extract_semantic_annotations(activations, full_test, tokenizer, feat_ids_annot, top_k=10)
for ann in annotations:
    print(f"Латент #{ann['feature_id']} | Топ-токены: {[t[0] for t in ann['top_tokens'][:10]]}")
# Out:
# Латент #10304 | Топ-токены: ['.', 'is', 'the', 'if', 'then', 'not', 'are', 'red', 'big', 'cow']
# Латент #48 | Топ-токены: ['the', '.', 'is', 'lion', 'cat', 'if', 'then', 'dog', 'and', 'eats']
# Латент #6640 | Топ-токены: ['the', '.', 'is', 'mouse', 'tiger', 'rabbit', 'if', 'then', 'cat', 'eats']
# Латент #8095 | Топ-токены: ['.', 'is', 'the', 'not', 'if', 'then', 'tiger', 'cow', 'are', 'dave']

# %%
top_idx = np.argsort(activations[:, fid])[::-1][0]
compare_attributions(latent_idx=fid, example_idx=int(top_idx))
# Out:
# IG для латента 10304: 100%|██████████| 50/50 [00:46<00:00,  1.08it/s]
# Example #1046 | Latent #10304 | GT: False | Model: False (совпадает)
# <div style='line-height:1.5; padding:5px; background:#fff; border:1px solid #eee; border-radius:3px; margin-bottom:15px;'><div style='font-weight:bold; margin-bottom:5px; font-size:12px;'>Attention (Layer 34)</div><span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;"><|endoftext|></span> <span style="background-color:rgba(253, 174, 74, 0.63); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Dave</span> <span style="background-color:rgba(254, 223, 130, 0.53); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 236, 158, 0.48); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">green</span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(254, 226, 138, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Fiona</span> <span style="background-color:rgba(255, 247, 184, 0.44); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 213, 113, 0.56); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">quiet</span> <span style="background-color:rgba(254, 203, 103, 0.58); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(255, 245, 181, 0.44); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Harry</span> <span style="background-color:rgba(255, 248, 188, 0.43); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 216, 117, 0.55); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">blue</span> <span style="background-color:rgba(254, 221, 128, 0.53); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(254, 194, 93, 0.59); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Smart</span> <span style="background-color:rgba(255, 250, 192, 0.42); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">,</span> <span style="background-color:rgba(254, 205, 105, 0.57); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">big</span> <span style="background-color:rgba(255, 244, 179, 0.44); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">people</span> <span style="background-color:rgba(255, 253, 201, 0.41); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">are</span> <span style="background-color:rgba(255, 238, 162, 0.47); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">blue</span> <span style="background-color:rgba(252, 110, 51, 0.74); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(255, 249, 190, 0.42); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">If</span> <span style="background-color:rgba(255, 254, 202, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Harry</span> <span style="background-color:rgba(255, 252, 197, 0.41); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(255, 252, 198, 0.41); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">not</span> <span style="background-color:rgba(254, 205, 105, 0.57); color:black; padding:2px 0px; margin:1px; border-radi ...
# <div style='line-height:1.5; padding:5px; background:#fff; border:1px solid #eee; border-radius:3px; margin-bottom:15px;'><div style='font-weight:bold; margin-bottom:5px; font-size:12px;'>Gradient Saliency</div><span style="background-color:rgba(218, 20, 30, 0.87); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;"><|endoftext|></span> <span style="background-color:rgba(250, 75, 41, 0.78); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Dave</span> <span style="background-color:rgba(254, 208, 108, 0.57); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 186, 84, 0.61); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">green</span> <span style="background-color:rgba(254, 232, 150, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(227, 28, 28, 0.85); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Fiona</span> <span style="background-color:rgba(254, 228, 141, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(253, 176, 75, 0.63); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">quiet</span> <span style="background-color:rgba(254, 221, 126, 0.54); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Harry</span> <span style="background-color:rgba(254, 213, 113, 0.56); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(129, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">blue</span> <span style="background-color:rgba(254, 179, 78, 0.62); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(221, 22, 29, 0.86); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Smart</span> <span style="background-color:rgba(255, 252, 198, 0.41); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">,</span> <span style="background-color:rgba(255, 242, 173, 0.45); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">big</span> <span style="background-color:rgba(254, 216, 117, 0.55); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">people</span> <span style="background-color:rgba(255, 246, 183, 0.44); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">are</span> <span style="background-color:rgba(254, 211, 112, 0.56); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">blue</span> <span style="background-color:rgba(255, 240, 169, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(254, 216, 117, 0.55); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">If</span> <span style="background-color:rgba(254, 226, 138, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Harry</span> <span style="background-color:rgba(255, 251, 194, 0.42); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(255, 245, 181, 0.44); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">not</span> <span style="background-color:rgba(254, 223, 132, 0.53); color:black; padding:2px 0px; margin:1px; border-radius:3px; fon ...
# <div style='line-height:1.5; padding:5px; background:#fff; border:1px solid #eee; border-radius:3px; margin-bottom:15px;'><div style='font-weight:bold; margin-bottom:5px; font-size:12px;'>IG (Latent #10304)</div><span style="background-color:rgba(232, 119, 93, 0.79); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;"><|endoftext|></span> <span style="background-color:rgba(179, 3, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Dave</span> <span style="background-color:rgba(245, 191, 165, 0.57); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(247, 177, 148, 0.62); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">green</span> <span style="background-color:rgba(237, 207, 192, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(242, 145, 115, 0.72); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Fiona</span> <span style="background-color:rgba(239, 206, 188, 0.50); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(246, 188, 162, 0.58); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">quiet</span> <span style="background-color:rgba(237, 207, 192, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(244, 194, 170, 0.56); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Harry</span> <span style="background-color:rgba(237, 208, 193, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(244, 194, 170, 0.56); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">blue</span> <span style="background-color:rgba(240, 204, 185, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(244, 194, 170, 0.56); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Smart</span> <span style="background-color:rgba(236, 209, 195, 0.48); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">,</span> <span style="background-color:rgba(246, 187, 160, 0.58); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">big</span> <span style="background-color:rgba(239, 206, 188, 0.50); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">people</span> <span style="background-color:rgba(234, 211, 199, 0.47); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">are</span> <span style="background-color:rgba(244, 194, 170, 0.56); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">blue</span> <span style="background-color:rgba(240, 204, 185, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(237, 207, 192, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">If</span> <span style="background-color:rgba(242, 200, 179, 0.53); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">Harry</span> <span style="background-color:rgba(232, 213, 202, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(234, 211, 199, 0.47); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">not</span> <span style="background-color:rgba(240, 204, 185, 0.51); color:black; padding:2px 0px; margin:1px; border-r ...

# %%
fid = 11723
feat_ids_annot = list({fid} | set(np.argsort(np.abs(corr_label))[::-1][:3].tolist()))
annotations = extract_semantic_annotations(activations, full_test, tokenizer, feat_ids_annot, top_k=10)
for ann in annotations:
    print(f"Латент #{ann['feature_id']} | Топ-токены: {[t[0] for t in ann['top_tokens'][:10]]}")
# Out:
# Латент #48 | Топ-токены: ['the', '.', 'is', 'lion', 'cat', 'if', 'then', 'dog', 'and', 'eats']
# Латент #11723 | Топ-токены: ['.', 'the', 'is', 'squirrel', 'cow', 'if', 'then', 'not', 'red', 'lion']
# Латент #6640 | Топ-токены: ['the', '.', 'is', 'mouse', 'tiger', 'rabbit', 'if', 'then', 'cat', 'eats']
# Латент #8095 | Топ-токены: ['.', 'is', 'the', 'not', 'if', 'then', 'tiger', 'cow', 'are', 'dave']

# %%
top_idx = np.argsort(activations[:, fid])[::-1][0]
compare_attributions(latent_idx=fid, example_idx=int(top_idx))
# Out:
# IG для латента 11723: 100%|██████████| 50/50 [00:49<00:00,  1.01it/s]
# Example #1999 | Latent #11723 | GT: False | Model: True (не совпадает)
# <div style='line-height:1.5; padding:5px; background:#fff; border:1px solid #eee; border-radius:3px; margin-bottom:15px;'><div style='font-weight:bold; margin-bottom:5px; font-size:12px;'>Attention (Layer 34)</div><span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;"><|endoftext|></span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(254, 233, 151, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(255, 242, 172, 0.45); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(242, 57, 36, 0.80); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">big</span> <span style="background-color:rgba(253, 157, 67, 0.67); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 248, 188, 0.43); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(255, 252, 197, 0.41); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(235, 44, 32, 0.82); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">blue</span> <span style="background-color:rgba(254, 186, 84, 0.61); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(252, 112, 51, 0.73); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 250, 192, 0.42); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(255, 253, 201, 0.41); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 197, 96, 0.59); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">kind</span> <span style="background-color:rgba(254, 231, 149, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(254, 178, 76, 0.62); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 249, 191, 0.42); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(255, 252, 198, 0.41); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 228, 142, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">red</span> <span style="background-color:rgba(254, 236, 159, 0.48); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(254, 186, 84, 0.61); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 249, 190, 0.42); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(255, 253, 201, 0.41); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(255, 239, 166, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-f ...
# <div style='line-height:1.5; padding:5px; background:#fff; border:1px solid #eee; border-radius:3px; margin-bottom:15px;'><div style='font-weight:bold; margin-bottom:5px; font-size:12px;'>Gradient Saliency</div><span style="background-color:rgba(128, 0, 38, 0.95); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;"><|endoftext|></span> <span style="background-color:rgba(254, 210, 111, 0.56); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(227, 28, 28, 0.85); color:white; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(254, 227, 140, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 218, 121, 0.54); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">big</span> <span style="background-color:rgba(254, 233, 151, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(255, 239, 166, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(254, 195, 95, 0.59); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(255, 240, 169, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 228, 142, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">blue</span> <span style="background-color:rgba(255, 240, 168, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(255, 245, 180, 0.44); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(254, 230, 145, 0.50); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(255, 248, 188, 0.43); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 231, 149, 0.49); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">kind</span> <span style="background-color:rgba(255, 244, 177, 0.44); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(255, 248, 188, 0.43); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 240, 169, 0.46); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(255, 249, 190, 0.43); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(255, 247, 186, 0.43); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">red</span> <span style="background-color:rgba(255, 247, 184, 0.43); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(255, 249, 190, 0.42); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(255, 242, 173, 0.45); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(255, 248, 187, 0.43); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(254, 227, 140, 0.51); color:black; padding:2px 0px; margin:1px; border-radius:3 ...
# <div style='line-height:1.5; padding:5px; background:#fff; border:1px solid #eee; border-radius:3px; margin-bottom:15px;'><div style='font-weight:bold; margin-bottom:5px; font-size:12px;'>IG (Latent #11723)</div><span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;"><|endoftext|></span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">big</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">blue</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">kind</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">red</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">.</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">The</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">mouse</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-radius:3px; font-family:monospace;">is</span> <span style="background-color:rgba(221, 220, 219, 0.40); color:black; padding:2px 0px; margin:1px; border-r ...
